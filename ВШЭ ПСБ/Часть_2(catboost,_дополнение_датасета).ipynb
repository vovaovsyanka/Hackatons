# %%
# !pip install catboost
# !pip install optuna
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 9.6 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 15.4 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-4.0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
dataweather = pd.read_excel('погода.xls')
dataweather
# Out:
#      Местное время в Москве (ВДНХ)   T_М  \
# 0                 21.09.2024 15:00  21.9
# 1                 21.09.2024 12:00  19.6
# 2                 21.09.2024 09:00  15.1
# 3                 21.09.2024 06:00  11.5
# 4                 21.09.2024 03:00  14.6
# ...                            ...   ...
# 7948              01.01.2022 12:00  -0.7
# 7949              01.01.2022 09:00  -1.4
# 7950              01.01.2022 06:00  -1.5
# 7951              01.01.2022 03:00  -1.9
# 7952              01.01.2022 00:00  -2.8
#
#                                                    W1_М   T_С  \
# 0                                                   NaN  22.0
# 1                                                   NaN  19.2
# 2                                                   NaN  16.5
# 3                                                   NaN  16.8
# 4                                                   NaN  17.7
# ...                                                 ...   ...
# 7948  Облака покрывали более половины неба в течение...   9.1
# 7949                          Снег или дождь со снегом.   6.1
# 7950                          Снег или дождь со снегом.   6.7
# 7951                          Снег или дождь со снегом.   7.7
# 7952                          Снег или дождь со снегом.   8.5
#
#                                        W1_С   T_К W1_К
# 0                           Ливень (ливни).  27.1  NaN
# 1                           Ливень (ливни).  24.0  NaN
# 2                           Ливень (ливни).  20.3  NaN
# 3                           Ливень (ливни).  12.1  NaN
# 4     Гроза (грозы) с осадками или без них.  14.2  NaN
# ...                                     ...   ...  ...
# 7948                        Ливень (ливни).   NaN  NaN
# 7949                        Ливень (ливни).   NaN  NaN
# 7950                        Ливень (ливни).   NaN  NaN
# 7951                        Ливень (ливни).   NaN  NaN
# 7952                        Ливень (ливни).   NaN  NaN
#
# [7953 rows x 7 columns]

# %%
dataweather['date'] = pd.to_datetime(dataweather['Местное время в Москве (ВДНХ)'], format='%d.%m.%Y %H:%M')

result = dataweather.groupby(dataweather['date'].dt.date).agg(
    average_temperature_M=('T_М', 'mean'),
    first_weather_M=('W1_М', 'first'),
    average_temperature_K=('T_К', 'mean'),
    first_weather_K=('W1_К', 'first'),
    average_temperature_C=('T_С', 'mean'),
    first_weather_C=('W1_С', 'first')
).reset_index()

result['Year'] = result['date'].apply(lambda x: x.year)
result['month'] = result['date'].apply(lambda x: x.month)
result['day'] = result['date'].apply(lambda x: x.day)

result['first_weather_K'] = result['first_weather_K'].fillna('Хорошая погода')
result['first_weather_M'] = result['first_weather_M'].fillna('Хорошая погода')
result['first_weather_C'] = result['first_weather_M'].fillna('Хорошая погода')
result = result.drop(columns=['date'])
print("Столбцы в dataweather:", result.columns)
result.to_csv("Погода.csv")
result.info()
# Out:
# Столбцы в dataweather: Index(['average_temperature_M', 'first_weather_M', 'average_temperature_K',
#        'first_weather_K', 'average_temperature_C', 'first_weather_C', 'Year',
#        'month', 'day'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   average_temperature_M  995 non-null    float64
#  1   first_weather_M        995 non-null    object
#  2   average_temperature_K  995 non-null    float64
#  3   first_weather_K        995 non-null    object
#  4   average_temperature_C  995 non-null    float64
#  5   first_weather_C        995 non-null    object
#  6   Year                   995 non-null    int64
#  7   month                  995 non-null    int64
#  8   day                    995 non-null    int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 70.1+ KB

# %%
dataInfl = pd.read_excel('Инфляция и ключевая ставка Банка России_F01_01_2022_T31_12_2023.xlsx')

# %%
dataInfl
# Out:
#      Год  Месяц  Ключевая ставка  Инфляция
# 0   2023     12             16.0      7.42
# 1   2023     11             15.0      7.48
# 2   2023     10             15.0      6.69
# 3   2023      9             13.0      6.00
# 4   2023      8             12.0      5.15
# 5   2023      7              8.5      4.30
# 6   2023      6              7.5      3.25
# 7   2023      5              7.5      2.51
# 8   2023      4              7.5      2.31
# 9   2023      3              7.5      3.51
# 10  2023      2              7.5     10.99
# 11  2023      1              7.5     11.77
# 12  2022     12              7.5     11.94
# 13  2022     11              7.5     11.98
# 14  2022     10              7.5     12.63
# 15  2022      9              7.5     13.68
# 16  2022      8              8.0     14.30
# 17  2022      7              8.0     15.10
# 18  2022      6              9.5     15.90
# 19  2022      5             11.0     17.10
# 20  2022      4             17.0     17.83
# 21  2022      3             20.0     16.69
# 22  2022      2             20.0      9.15
# 23  2022      1              8.5      8.73

# %%
data = pd.read_excel('data.xlsx')

# %%
data = pd.read_excel('test.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-bc89c71d03bf> in <cell line: 1>()
# ----> 1 data = pd.read_excel('test.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     515
#     516     try:
# --> 517         data = io.parse(
#     518             sheet_name=sheet_name,
#     519             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1627         >>> file.parse()  # doctest: +SKIP
#    1628         """
# -> 1629         return self._reader.parse(
#    1630             sheet_name=sheet_name,
#    1631             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     791
#     792             file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 793             data = self.get_sheet_data(sheet, file_rows_needed)
#     794             if hasattr(sheet, "close"):
#     795                 # pyxlsb opens two TemporaryFiles
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in get_sheet_data(self, sheet, file_rows_needed)
#     614         data: list[list[Scalar]] = []
#     615         last_row_with_data = -1
# --> 616         for row_number, row in enumerate(sheet.rows):
#     617             converted_row = [self._convert_cell(cell) for cell in row]
#     618             while converted_row and converted_row[-1] == "":
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_read_only.py in _cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      83                                      timedelta_formats=self.parent._timedelta_formats)
#      84
# ---> 85             for idx, row in parser.parse():
#      86                 if max_row is not None and idx > max_row:
#      87                     break
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py in parse(self)
#     154         it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
#     155
# --> 156         for _, element in it:
#     157             tag_name = element.tag
#     158             if tag_name in dispatcher:
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in iterator(source)
#    1251             yield None
#    1252             while True:
# -> 1253                 yield from pullparser.read_events()
#    1254                 # load event buffer
#    1255                 data = source.read(16 * 1024)
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in read_events(self)
#    1324                 raise event
#    1325             else:
# -> 1326                 yield event
#    1327
#    1328
#
# KeyboardInterrupt:

# %%
from sklearn.preprocessing import LabelEncoder
def encode_columns(df):
    le = LabelEncoder()
    for column in data.select_dtypes(include=['object']).columns:
        df[column] = le.fit_transform(df[column])
    return df
data = encode_columns(data)
data
# Out:
#        Номеров  Стоимость  Внесена предоплата  Способ оплаты  \
# 0            1    25700.0                   0              6
# 1            1    24800.0               12400             11
# 2            1    25800.0               12900              4
# 3            1    10500.0                   0              9
# 4            1    28690.0               28690             13
# ...        ...        ...                 ...            ...
# 26169        1    18240.0                9120              4
# 26170        1    69600.0               23200              4
# 26171        1    55600.0               13900              4
# 26172        1     6300.0                   0             10
# 26173        1    24600.0               24600              4
#
#         Дата бронирования               Заезд  Ночей               Выезд  \
# 0     2023-04-20 20:37:30 2023-04-28 15:00:00      3 2023-05-01 12:00:00
# 1     2022-06-18 14:17:02 2022-07-11 15:00:00      2 2022-07-13 12:00:00
# 2     2022-11-14 22:59:30 2022-12-04 15:00:00      2 2022-12-06 12:00:00
# 3     2023-09-08 15:55:53 2023-09-18 15:00:00      1 2023-09-19 12:00:00
# 4     2023-05-20 19:54:13 2023-05-29 15:00:00      2 2023-05-31 12:00:00
# ...                   ...                 ...    ...                 ...
# 26169 2023-01-07 17:45:18 2023-03-10 15:00:00      2 2023-03-12 12:00:00
# 26170 2023-06-20 17:54:17 2023-06-25 15:00:00      3 2023-06-28 12:00:00
# 26171 2022-05-08 19:24:05 2022-06-24 15:00:00      4 2022-06-28 12:00:00
# 26172 2022-02-19 09:55:50 2022-04-27 15:00:00      1 2022-04-28 12:00:00
# 26173 2022-08-13 22:35:43 2022-08-16 15:00:00      1 2022-08-17 12:00:00
#
#        Источник  Категория номера  Гостей  Гостиница  Target
# 0            26                25       2          1       1
# 1            23                25       2          1       0
# 2            23                27       2          4       0
# 3             9                25       1          3       0
# 4            23                24       4          1       0
# ...         ...               ...     ...        ...     ...
# 26169        23                25       2          2       0
# 26170        23                27       3          4       0
# 26171        23                25       2          2       0
# 26172        17                25       2          3       1
# 26173        23                21       3          1       0
#
# [26174 rows x 13 columns]

# %%
data['Дата бронирования'] = pd.to_datetime(data['Дата бронирования'])
data['year_Дата бронирования'] = data['Дата бронирования'].dt.year.astype('int64')
data['month_Дата бронирования'] = data['Дата бронирования'].dt.month.astype('int64')
data['day_Дата бронирования'] = data['Дата бронирования'].dt.day.astype('int64')
data['day_of_week_Дата бронирования'] = data['Дата бронирования'].dt.dayofweek.astype('int64')
data.drop('Дата бронирования', axis=1, inplace=True)
data['Заезд'] = pd.to_datetime(data['Заезд'])
data['month_Заезд'] = data['Заезд'].dt.month.astype('int64')
data['day_Заезд'] = data['Заезд'].dt.day.astype('int64')
data['day_of_week_Заезд'] = data['Заезд'].dt.dayofweek.astype('int64')
data.drop('Заезд', axis=1, inplace=True)
data.drop('Выезд', axis=1, inplace=True)

# %%
def определить_сезон(month):
    if month == 12 or month < 3:
        return 1
    elif 2 < month < 6:
        return 2
    elif 5 < month < 9:
        return 3
    elif 8 < month < 12:
        return 4

data['Сезон'] = data['month_Заезд'].apply(определить_сезон)

data = data.merge(dataInfl, left_on=['month_Дата бронирования', 'year_Дата бронирования'],
                  right_on=['Месяц', 'Год'], how='left')
data.drop(['Год', 'Месяц'], axis=1, inplace=True)
data.head()
print("Столбцы в data:", data.columns)
# data = data.merge(dataweather, left_on=['year_Дата бронирования', 'month_Дата бронирования', 'day_Дата бронирования'],
#                   right_on=['Year', 'month', 'day'], how='left')

# data.drop(['Год1', 'Месяц1', 'year_Дата бронирования', 'День1'], axis=1, inplace=True)

data.head()
# Out:
# Столбцы в data: Index(['Номеров', 'Стоимость', 'Внесена предоплата', 'Способ оплаты', 'Ночей',
#        'Источник', 'Категория номера', 'Гостей', 'Гостиница', 'Target',
#        'year_Дата бронирования', 'month_Дата бронирования',
#        'day_Дата бронирования', 'day_of_week_Дата бронирования', 'month_Заезд',
#        'day_Заезд', 'day_of_week_Заезд', 'Сезон', 'Ключевая ставка',
#        'Инфляция'],
#       dtype='object')
#    Номеров  Стоимость  Внесена предоплата  \
# 0        1    25700.0                   0
# 1        1    24800.0               12400
# 2        1    25800.0               12900
# 3        1    10500.0                   0
# 4        1    28690.0               28690
#
#                                        Способ оплаты  Ночей  \
# 0                             Внешняя система оплаты      3
# 1  Отложенная электронная оплата: Банк Россия (ба...      2
# 2             Банк. карта: Банк Россия (банк. карта)      2
# 3             Внешняя система оплаты (С предоплатой)      1
# 4  Система быстрых платежей: Эквайринг ComfortBoo...      2
#
#              Источник  Категория номера  Гостей  Гостиница  Target  \
# 0  Яндекс.Путешествия  Номер «Стандарт»       2          1       1
# 1    Официальный сайт  Номер «Стандарт»       2          1       0
# 2    Официальный сайт    Номер «Студия»       2          4       0
# 3   Bronevik.com(new)  Номер «Стандарт»       1          3       0
# 4    Официальный сайт      Номер «Люкс»       4          1       0
#
#    year_Дата бронирования  month_Дата бронирования  day_Дата бронирования  \
# 0                    2023                        4                     20
# 1                    2022                        6                     18
# 2                    2022                       11                     14
# 3                    2023                        9                      8
# 4                    2023                        5                     20
#
#    day_of_week_Дата бронирования  month_Заезд  day_Заезд  day_of_week_Заезд  \
# 0                              3            4         28                  4
# 1                              5            7         11                  0
# 2                              0           12          4                  6
# 3                              4            9         18                  0
# 4                              5            5         29                  0
#
#    Сезон  Ключевая ставка  Инфляция
# 0      2              7.5      2.31
# 1      3              9.5     15.90
# 2      1              7.5     11.98
# 3      4             13.0      6.00
# 4      2              7.5      2.51

# %%
y = data['Target']
data = data.drop('Target', axis=1)
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.7, random_state=42)

# %%
from catboost import CatBoostClassifier
cat_features = ['Способ оплаты', 'Источник', 'Категория номера']

model = CatBoostClassifier(iterations=801, learning_rate=0.03428285642946706, depth=4, random_seed=42, cat_features=cat_features, verbose=100)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)

print(classification_report(y_test, y_pred))
print(f'ROC-AUC: {roc_auc_score(y_test, y_pred_proba[:, 1])}')
# Out:
# 0:	learn: 0.6705594	total: 11ms	remaining: 8.77s
# 100:	learn: 0.3327717	total: 943ms	remaining: 6.54s
# 200:	learn: 0.3206148	total: 1.9s	remaining: 5.66s
# 300:	learn: 0.3124358	total: 2.82s	remaining: 4.68s
# 400:	learn: 0.3041867	total: 3.77s	remaining: 3.77s
# 500:	learn: 0.2961229	total: 4.72s	remaining: 2.83s
# 600:	learn: 0.2881077	total: 5.68s	remaining: 1.89s
# 700:	learn: 0.2811403	total: 7.79s	remaining: 1.11s
# 800:	learn: 0.2754235	total: 10.2s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     14710
#            1       0.95      0.51      0.67      3612
#
#     accuracy                           0.90     18322
#    macro avg       0.92      0.75      0.80     18322
# weighted avg       0.90      0.90      0.89     18322
#
# ROC-AUC: 0.8360913146976654

# %%
import optuna
from catboost import CatBoostClassifier

cat_features = ['Способ оплаты', 'Источник', 'Категория номера']

def objective(trial):
    # Подбор гиперпараметров
    iterations = trial.suggest_int('iterations', 500, 1500)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.4)
    depth = trial.suggest_int('depth', 4, 12)
    l2_leaf_reg = trial.suggest_int('l2_leaf_reg', 3, 15)
    random_strength = trial.suggest_int('random_strength', 1, 10)

    model = CatBoostClassifier(iterations=iterations,
                               learning_rate=learning_rate,
                               depth=depth,
                               random_seed=42,
                               cat_features=cat_features,
                               l2_leaf_reg = l2_leaf_reg,
                               random_strength=random_strength,
                               verbose=0)

    model.fit(X_train, y_train)
    y_pred_proba = model.predict_proba(X_test)

    # Оценка модели
    return roc_auc_score(y_test, y_pred_proba[:, 1])

# Запуск оптимизации
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Вывод наилучших гиперпараметров
print("Best hyperparameters: ", study.best_params)
print("Best AUC: ", study.best_value)
# Out:
# [I 2024-09-21 15:24:35,971] A new study created in memory with name: no-name-4fa9f815-88c7-4819-96d9-d3806b7ff550
# [I 2024-09-21 15:24:42,979] Trial 0 finished with value: 0.8168037202075114 and parameters: {'iterations': 554, 'learning_rate': 0.34568753198713137, 'depth': 4, 'l2_leaf_reg': 12, 'random_strength': 5}. Best is trial 0 with value: 0.8168037202075114.
# [I 2024-09-21 15:25:10,399] Trial 1 finished with value: 0.812049155583059 and parameters: {'iterations': 749, 'learning_rate': 0.3182676701747498, 'depth': 10, 'l2_leaf_reg': 4, 'random_strength': 2}. Best is trial 0 with value: 0.8168037202075114.
# [I 2024-09-21 15:25:18,099] Trial 2 finished with value: 0.8170759640235397 and parameters: {'iterations': 538, 'learning_rate': 0.1558666023120334, 'depth': 7, 'l2_leaf_reg': 12, 'random_strength': 7}. Best is trial 2 with value: 0.8170759640235397.
# [I 2024-09-21 15:25:52,328] Trial 3 finished with value: 0.8144757485622741 and parameters: {'iterations': 1136, 'learning_rate': 0.1477603275578765, 'depth': 9, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 2 with value: 0.8170759640235397.
# [I 2024-09-21 15:26:58,713] Trial 4 finished with value: 0.816567838303171 and parameters: {'iterations': 1364, 'learning_rate': 0.19741882870704996, 'depth': 11, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 2 with value: 0.8170759640235397.
# [I 2024-09-21 15:27:09,829] Trial 5 finished with value: 0.8326702554292549 and parameters: {'iterations': 1101, 'learning_rate': 0.018829332629879833, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 3}. Best is trial 5 with value: 0.8326702554292549.
# [I 2024-09-21 15:28:28,510] Trial 6 finished with value: 0.8161072729093218 and parameters: {'iterations': 1058, 'learning_rate': 0.3428979860143647, 'depth': 12, 'l2_leaf_reg': 15, 'random_strength': 4}. Best is trial 5 with value: 0.8326702554292549.
# [I 2024-09-21 15:28:38,192] Trial 7 finished with value: 0.8102523275764071 and parameters: {'iterations': 848, 'learning_rate': 0.3767285208770932, 'depth': 4, 'l2_leaf_reg': 6, 'random_strength': 10}. Best is trial 5 with value: 0.8326702554292549.
# [I 2024-09-21 15:28:46,394] Trial 8 finished with value: 0.8325537825045753 and parameters: {'iterations': 615, 'learning_rate': 0.07611139019234361, 'depth': 5, 'l2_leaf_reg': 7, 'random_strength': 3}. Best is trial 5 with value: 0.8326702554292549.
# [I 2024-09-21 15:29:00,702] Trial 9 finished with value: 0.8153002153859821 and parameters: {'iterations': 724, 'learning_rate': 0.18261419684111316, 'depth': 8, 'l2_leaf_reg': 9, 'random_strength': 8}. Best is trial 5 with value: 0.8326702554292549.
# [I 2024-09-21 15:29:16,602] Trial 10 finished with value: 0.8316348067059496 and parameters: {'iterations': 1211, 'learning_rate': 0.025733983921403886, 'depth': 6, 'l2_leaf_reg': 5, 'random_strength': 6}. Best is trial 5 with value: 0.8326702554292549.
# [I 2024-09-21 15:29:27,828] Trial 11 finished with value: 0.832901959101507 and parameters: {'iterations': 945, 'learning_rate': 0.016173103683476353, 'depth': 5, 'l2_leaf_reg': 6, 'random_strength': 3}. Best is trial 11 with value: 0.832901959101507.
# [I 2024-09-21 15:29:40,517] Trial 12 finished with value: 0.8330063866724183 and parameters: {'iterations': 948, 'learning_rate': 0.019985150087719557, 'depth': 6, 'l2_leaf_reg': 3, 'random_strength': 4}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:29:53,437] Trial 13 finished with value: 0.8239609188496988 and parameters: {'iterations': 908, 'learning_rate': 0.08250620074555605, 'depth': 6, 'l2_leaf_reg': 7, 'random_strength': 5}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:30:06,718] Trial 14 finished with value: 0.8120813769043893 and parameters: {'iterations': 904, 'learning_rate': 0.26813427163309195, 'depth': 6, 'l2_leaf_reg': 5, 'random_strength': 4}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:30:32,668] Trial 15 finished with value: 0.8162900611527554 and parameters: {'iterations': 1298, 'learning_rate': 0.08643427346014307, 'depth': 8, 'l2_leaf_reg': 8, 'random_strength': 1}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:30:48,306] Trial 16 finished with value: 0.8142926027224004 and parameters: {'iterations': 967, 'learning_rate': 0.12000762489480679, 'depth': 7, 'l2_leaf_reg': 5, 'random_strength': 4}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:31:06,311] Trial 17 finished with value: 0.8106100557624596 and parameters: {'iterations': 1484, 'learning_rate': 0.24207940143363765, 'depth': 5, 'l2_leaf_reg': 3, 'random_strength': 6}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:31:16,268] Trial 18 finished with value: 0.8221240588626325 and parameters: {'iterations': 832, 'learning_rate': 0.011777111697716128, 'depth': 5, 'l2_leaf_reg': 6, 'random_strength': 8}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:31:31,954] Trial 19 finished with value: 0.8263022533092728 and parameters: {'iterations': 1000, 'learning_rate': 0.05151309869388013, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 3}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:31:51,866] Trial 20 finished with value: 0.8173017579440991 and parameters: {'iterations': 698, 'learning_rate': 0.11628279245914515, 'depth': 9, 'l2_leaf_reg': 7, 'random_strength': 2}. Best is trial 12 with value: 0.8330063866724183.
# [I 2024-09-21 15:32:02,623] Trial 21 finished with value: 0.8335534057108528 and parameters: {'iterations': 1096, 'learning_rate': 0.043400100819848665, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 3}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:32:17,507] Trial 22 finished with value: 0.8289798789893646 and parameters: {'iterations': 1181, 'learning_rate': 0.0511917188827392, 'depth': 5, 'l2_leaf_reg': 4, 'random_strength': 4}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:32:28,365] Trial 23 finished with value: 0.8325012440591938 and parameters: {'iterations': 1047, 'learning_rate': 0.05222294361161741, 'depth': 4, 'l2_leaf_reg': 4, 'random_strength': 3}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:32:42,018] Trial 24 finished with value: 0.8177355977092748 and parameters: {'iterations': 952, 'learning_rate': 0.11166450908614078, 'depth': 6, 'l2_leaf_reg': 3, 'random_strength': 5}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:32:57,514] Trial 25 finished with value: 0.8320674795774791 and parameters: {'iterations': 1254, 'learning_rate': 0.04214861625596513, 'depth': 5, 'l2_leaf_reg': 6, 'random_strength': 2}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:33:06,216] Trial 26 finished with value: 0.8312006093443338 and parameters: {'iterations': 797, 'learning_rate': 0.07701137402948327, 'depth': 4, 'l2_leaf_reg': 4, 'random_strength': 1}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:33:20,514] Trial 27 finished with value: 0.8310658707699163 and parameters: {'iterations': 1089, 'learning_rate': 0.010827416212171953, 'depth': 6, 'l2_leaf_reg': 5, 'random_strength': 4}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:33:35,040] Trial 28 finished with value: 0.8148184576978468 and parameters: {'iterations': 898, 'learning_rate': 0.2389241293747652, 'depth': 7, 'l2_leaf_reg': 8, 'random_strength': 3}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:33:46,165] Trial 29 finished with value: 0.8240189435773044 and parameters: {'iterations': 1024, 'learning_rate': 0.14992926505943172, 'depth': 4, 'l2_leaf_reg': 14, 'random_strength': 5}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:34:00,276] Trial 30 finished with value: 0.8301640878317083 and parameters: {'iterations': 1172, 'learning_rate': 0.04146747694099648, 'depth': 5, 'l2_leaf_reg': 4, 'random_strength': 6}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:34:11,860] Trial 31 finished with value: 0.8303579427439165 and parameters: {'iterations': 1104, 'learning_rate': 0.011018385446355196, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 3}. Best is trial 21 with value: 0.8335534057108528.
# [I 2024-09-21 15:34:22,855] Trial 32 finished with value: 0.8352017559114455 and parameters: {'iterations': 981, 'learning_rate': 0.034136381957491246, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:34:35,417] Trial 33 finished with value: 0.8237256956756427 and parameters: {'iterations': 954, 'learning_rate': 0.09978803020720486, 'depth': 5, 'l2_leaf_reg': 4, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:34:42,853] Trial 34 finished with value: 0.831365762437016 and parameters: {'iterations': 785, 'learning_rate': 0.06515430206129576, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:34:56,861] Trial 35 finished with value: 0.8318064529971475 and parameters: {'iterations': 1006, 'learning_rate': 0.030586376638864612, 'depth': 6, 'l2_leaf_reg': 5, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:35:08,598] Trial 36 finished with value: 0.8216503188630992 and parameters: {'iterations': 905, 'learning_rate': 0.1298213733575173, 'depth': 5, 'l2_leaf_reg': 3, 'random_strength': 4}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:35:16,377] Trial 37 finished with value: 0.8184208089509024 and parameters: {'iterations': 634, 'learning_rate': 0.29630330031349644, 'depth': 4, 'l2_leaf_reg': 11, 'random_strength': 3}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:35:39,175] Trial 38 finished with value: 0.815087765458894 and parameters: {'iterations': 853, 'learning_rate': 0.09744162774802544, 'depth': 9, 'l2_leaf_reg': 6, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:37:08,053] Trial 39 finished with value: 0.8147131925984313 and parameters: {'iterations': 1141, 'learning_rate': 0.17371437029681136, 'depth': 12, 'l2_leaf_reg': 13, 'random_strength': 5}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:37:52,314] Trial 40 finished with value: 0.8168070891423934 and parameters: {'iterations': 1345, 'learning_rate': 0.0633281477385009, 'depth': 10, 'l2_leaf_reg': 4, 'random_strength': 10}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:38:04,055] Trial 41 finished with value: 0.8349068988258038 and parameters: {'iterations': 1095, 'learning_rate': 0.025867684535445787, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 3}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:38:15,753] Trial 42 finished with value: 0.8345363630409399 and parameters: {'iterations': 1068, 'learning_rate': 0.03226020259646112, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:38:27,726] Trial 43 finished with value: 0.8336895558501648 and parameters: {'iterations': 1071, 'learning_rate': 0.036377543224386924, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:38:39,440] Trial 44 finished with value: 0.8341932774880619 and parameters: {'iterations': 1066, 'learning_rate': 0.03428321585320198, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:38:51,109] Trial 45 finished with value: 0.8288447075350462 and parameters: {'iterations': 1059, 'learning_rate': 0.06654786210058276, 'depth': 4, 'l2_leaf_reg': 4, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:39:04,602] Trial 46 finished with value: 0.8113486429779728 and parameters: {'iterations': 1228, 'learning_rate': 0.38970446653349333, 'depth': 4, 'l2_leaf_reg': 5, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:39:18,463] Trial 47 finished with value: 0.831704632116075 and parameters: {'iterations': 1140, 'learning_rate': 0.03190938694851095, 'depth': 5, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:39:29,441] Trial 48 finished with value: 0.8230528497424929 and parameters: {'iterations': 1050, 'learning_rate': 0.1347993154183068, 'depth': 4, 'l2_leaf_reg': 4, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:39:43,188] Trial 49 finished with value: 0.8261023757201804 and parameters: {'iterations': 1249, 'learning_rate': 0.08927950975455551, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:40:40,063] Trial 50 finished with value: 0.8185133511454002 and parameters: {'iterations': 1119, 'learning_rate': 0.03581120240018558, 'depth': 11, 'l2_leaf_reg': 5, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:40:52,200] Trial 51 finished with value: 0.8307398181001014 and parameters: {'iterations': 1081, 'learning_rate': 0.05918055459107149, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:41:06,698] Trial 52 finished with value: 0.8317411257738199 and parameters: {'iterations': 1175, 'learning_rate': 0.029222524639999428, 'depth': 5, 'l2_leaf_reg': 3, 'random_strength': 2}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:41:16,134] Trial 53 finished with value: 0.8288155351938887 and parameters: {'iterations': 974, 'learning_rate': 0.07646808503796065, 'depth': 4, 'l2_leaf_reg': 4, 'random_strength': 3}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:41:27,117] Trial 54 finished with value: 0.833602528169189 and parameters: {'iterations': 1001, 'learning_rate': 0.04444267002936565, 'depth': 4, 'l2_leaf_reg': 3, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:41:39,374] Trial 55 finished with value: 0.8347301050279565 and parameters: {'iterations': 1008, 'learning_rate': 0.027423036278101238, 'depth': 5, 'l2_leaf_reg': 4, 'random_strength': 1}. Best is trial 32 with value: 0.8352017559114455.
# [I 2024-09-21 15:41:51,967] Trial 56 finished with value: 0.8357604815280736 and parameters: {'iterations': 1032, 'learning_rate': 0.0220673602600119, 'depth': 5, 'l2_leaf_reg': 5, 'random_strength': 1}. Best is trial 56 with value: 0.8357604815280736.
# [I 2024-09-21 15:42:04,436] Trial 57 finished with value: 0.8355011205943178 and parameters: {'iterations': 1024, 'learning_rate': 0.026216137228616633, 'depth': 5, 'l2_leaf_reg': 5, 'random_strength': 1}. Best is trial 56 with value: 0.8357604815280736.
# [I 2024-09-21 15:42:14,981] Trial 58 finished with value: 0.8330616165015323 and parameters: {'iterations': 872, 'learning_rate': 0.021441804531500335, 'depth': 5, 'l2_leaf_reg': 8, 'random_strength': 9}. Best is trial 56 with value: 0.8357604815280736.
# [I 2024-09-21 15:42:29,367] Trial 59 finished with value: 0.8238462997802476 and parameters: {'iterations': 1023, 'learning_rate': 0.06954461633070029, 'depth': 6, 'l2_leaf_reg': 6, 'random_strength': 1}. Best is trial 56 with value: 0.8357604815280736.
# [I 2024-09-21 15:42:42,317] Trial 60 finished with value: 0.8358459000250693 and parameters: {'iterations': 975, 'learning_rate': 0.021404550104014854, 'depth': 6, 'l2_leaf_reg': 7, 'random_strength': 7}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:42:53,974] Trial 61 finished with value: 0.8351109452365519 and parameters: {'iterations': 977, 'learning_rate': 0.02266086251227849, 'depth': 5, 'l2_leaf_reg': 7, 'random_strength': 7}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:43:06,192] Trial 62 finished with value: 0.8333832274471453 and parameters: {'iterations': 928, 'learning_rate': 0.018823904096525873, 'depth': 6, 'l2_leaf_reg': 7, 'random_strength': 7}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:43:16,756] Trial 63 finished with value: 0.8309476945569305 and parameters: {'iterations': 976, 'learning_rate': 0.05413557047555069, 'depth': 5, 'l2_leaf_reg': 9, 'random_strength': 7}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:43:28,768] Trial 64 finished with value: 0.834382182512706 and parameters: {'iterations': 1027, 'learning_rate': 0.021466277524374112, 'depth': 5, 'l2_leaf_reg': 7, 'random_strength': 7}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:43:44,288] Trial 65 finished with value: 0.8250845056850306 and parameters: {'iterations': 935, 'learning_rate': 0.05068800535333632, 'depth': 7, 'l2_leaf_reg': 5, 'random_strength': 8}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:43:56,024] Trial 66 finished with value: 0.8156800580887185 and parameters: {'iterations': 986, 'learning_rate': 0.21359959607648607, 'depth': 5, 'l2_leaf_reg': 8, 'random_strength': 6}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:44:04,209] Trial 67 finished with value: 0.8083964961571557 and parameters: {'iterations': 516, 'learning_rate': 0.35007848354877263, 'depth': 6, 'l2_leaf_reg': 6, 'random_strength': 8}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:44:14,601] Trial 68 finished with value: 0.8195177266201565 and parameters: {'iterations': 882, 'learning_rate': 0.010904189333952779, 'depth': 5, 'l2_leaf_reg': 5, 'random_strength': 9}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:44:28,922] Trial 69 finished with value: 0.8213143664181559 and parameters: {'iterations': 1028, 'learning_rate': 0.08863337629609878, 'depth': 6, 'l2_leaf_reg': 7, 'random_strength': 6}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:44:38,471] Trial 70 finished with value: 0.8320967460229629 and parameters: {'iterations': 818, 'learning_rate': 0.04581393533022267, 'depth': 5, 'l2_leaf_reg': 6, 'random_strength': 7}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:44:52,020] Trial 71 finished with value: 0.8336832320394365 and parameters: {'iterations': 1120, 'learning_rate': 0.026795570345930372, 'depth': 5, 'l2_leaf_reg': 4, 'random_strength': 1}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:45:09,800] Trial 72 finished with value: 0.834636734715387 and parameters: {'iterations': 938, 'learning_rate': 0.021874856935661924, 'depth': 8, 'l2_leaf_reg': 9, 'random_strength': 2}. Best is trial 60 with value: 0.8358459000250693.
# [I 2024-09-21 15:45:24,480] Trial 73 finished with value: 0.8359534989117775 and parameters: {'iterations': 936, 'learning_rate': 0.020712159893039355, 'depth': 7, 'l2_leaf_reg': 9, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:45:38,531] Trial 74 finished with value: 0.8353925242017506 and parameters: {'iterations': 914, 'learning_rate': 0.011008995883610359, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:45:52,588] Trial 75 finished with value: 0.835104301471114 and parameters: {'iterations': 907, 'learning_rate': 0.01103096964899167, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:46:09,372] Trial 76 finished with value: 0.8350158622252436 and parameters: {'iterations': 917, 'learning_rate': 0.010133306218731153, 'depth': 8, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:46:23,242] Trial 77 finished with value: 0.8272654299099685 and parameters: {'iterations': 865, 'learning_rate': 0.05784403835147024, 'depth': 7, 'l2_leaf_reg': 11, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:46:36,366] Trial 78 finished with value: 0.8316980165819351 and parameters: {'iterations': 779, 'learning_rate': 0.04343622282486573, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:46:50,094] Trial 79 finished with value: 0.8248722627874604 and parameters: {'iterations': 839, 'learning_rate': 0.07059942482988846, 'depth': 7, 'l2_leaf_reg': 11, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:47:01,939] Trial 80 finished with value: 0.823304465890193 and parameters: {'iterations': 895, 'learning_rate': 0.010323402730139741, 'depth': 6, 'l2_leaf_reg': 10, 'random_strength': 7}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:47:21,184] Trial 81 finished with value: 0.8335449363214844 and parameters: {'iterations': 961, 'learning_rate': 0.016902022528387944, 'depth': 8, 'l2_leaf_reg': 9, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:47:35,911] Trial 82 finished with value: 0.8310308263187969 and parameters: {'iterations': 917, 'learning_rate': 0.038957209389745735, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:47:49,194] Trial 83 finished with value: 0.8316384767746757 and parameters: {'iterations': 738, 'learning_rate': 0.011434108334518956, 'depth': 8, 'l2_leaf_reg': 12, 'random_strength': 2}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:48:14,812] Trial 84 finished with value: 0.8202052340073461 and parameters: {'iterations': 916, 'learning_rate': 0.05177736799280189, 'depth': 9, 'l2_leaf_reg': 9, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:48:33,314] Trial 85 finished with value: 0.8326868742532821 and parameters: {'iterations': 978, 'learning_rate': 0.024475613859697952, 'depth': 8, 'l2_leaf_reg': 8, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:48:46,705] Trial 86 finished with value: 0.8301883855687628 and parameters: {'iterations': 820, 'learning_rate': 0.036781964711691414, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 2}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:48:59,295] Trial 87 finished with value: 0.8352475847183607 and parameters: {'iterations': 944, 'learning_rate': 0.020014747420911586, 'depth': 6, 'l2_leaf_reg': 11, 'random_strength': 9}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:49:12,669] Trial 88 finished with value: 0.8297459446681619 and parameters: {'iterations': 955, 'learning_rate': 0.05958807447160284, 'depth': 6, 'l2_leaf_reg': 12, 'random_strength': 9}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:49:24,641] Trial 89 finished with value: 0.8317435160237083 and parameters: {'iterations': 880, 'learning_rate': 0.04461532954361779, 'depth': 6, 'l2_leaf_reg': 11, 'random_strength': 8}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:49:40,273] Trial 90 finished with value: 0.8338659073576786 and parameters: {'iterations': 1041, 'learning_rate': 0.020624959324975628, 'depth': 7, 'l2_leaf_reg': 11, 'random_strength': 9}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:50:02,933] Trial 91 finished with value: 0.8256145388925653 and parameters: {'iterations': 993, 'learning_rate': 0.010443888499922655, 'depth': 8, 'l2_leaf_reg': 10, 'random_strength': 8}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:50:20,666] Trial 92 finished with value: 0.8324048247664518 and parameters: {'iterations': 949, 'learning_rate': 0.030856630622145876, 'depth': 7, 'l2_leaf_reg': 9, 'random_strength': 10}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:50:37,449] Trial 93 finished with value: 0.8344988906982014 and parameters: {'iterations': 919, 'learning_rate': 0.01902866155905992, 'depth': 8, 'l2_leaf_reg': 10, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:50:49,282] Trial 94 finished with value: 0.8326325760569986 and parameters: {'iterations': 855, 'learning_rate': 0.03758938980090436, 'depth': 6, 'l2_leaf_reg': 11, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:51:05,754] Trial 95 finished with value: 0.8122542653726945 and parameters: {'iterations': 1014, 'learning_rate': 0.2825573901338482, 'depth': 7, 'l2_leaf_reg': 10, 'random_strength': 5}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:51:30,140] Trial 96 finished with value: 0.8295040400869373 and parameters: {'iterations': 889, 'learning_rate': 0.02739120101887262, 'depth': 9, 'l2_leaf_reg': 13, 'random_strength': 1}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:51:43,510] Trial 97 finished with value: 0.8353157350714778 and parameters: {'iterations': 967, 'learning_rate': 0.017654410807374142, 'depth': 6, 'l2_leaf_reg': 8, 'random_strength': 2}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:51:57,710] Trial 98 finished with value: 0.8137495078343733 and parameters: {'iterations': 986, 'learning_rate': 0.16891643251074068, 'depth': 6, 'l2_leaf_reg': 8, 'random_strength': 2}. Best is trial 73 with value: 0.8359534989117775.
# [I 2024-09-21 15:52:11,409] Trial 99 finished with value: 0.8276564145649407 and parameters: {'iterations': 964, 'learning_rate': 0.048156901378948805, 'depth': 6, 'l2_leaf_reg': 7, 'random_strength': 2}. Best is trial 73 with value: 0.8359534989117775.
# Best hyperparameters:  {'iterations': 936, 'learning_rate': 0.020712159893039355, 'depth': 7, 'l2_leaf_reg': 9, 'random_strength': 1}
# Best AUC:  0.8359534989117775

# %%
y_pred = model.predict(data)
y_pred_proba = model.predict_proba(data)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
if y_test.ndim == 2:
   y_test = y_test.flatten()
roc_auc = roc_auc_score(y_test, y_pred_proba[:, 1])
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[:, 1])

# Построение ROC-кривой
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Линия случайного угадывания
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# Выводим отчёт
print(classification_report(y_test, y_pred))
print(f'ROC-AUC: {roc_auc}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     14710
#            1       0.98      0.51      0.67      3612
#
#     accuracy                           0.90     18322
#    macro avg       0.93      0.75      0.80     18322
# weighted avg       0.91      0.90      0.89     18322
#
# ROC-AUC: 0.8338231839935316
